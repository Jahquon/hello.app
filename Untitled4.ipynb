# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahquon/hello.app/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# !pip install plotly
import plotly.express as px
import plotly.graph_objects as go
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.0)

# %% [markdown]
# # Load the Dataset

# %%
rehab = pd.read_csv('/content/Rehabs_of_Vacant_Buildings.csv')

# %% [markdown]
# # Data Overview

# %%
rehab2 = rehab.copy()
rehab2.head()
# Out:
#               X              Y  OBJECTID Block  Lot      PermitNum VBN  \
# 0  1.411621e+06  588083.607549        11  0702  054  USE2017-53053   Y
# 1  1.412010e+06  588243.692202        17  0703  003  USE2016-04684   Y
# 2  1.411996e+06  588238.767015        18  0703  004  USE2018-56446   Y
# 3  1.411971e+06  588228.203388        20  0703  006  USE2018-52199   Y
# 4  1.411933e+06  588211.727043        23  0703  009  USE2019-52486   Y
#
#                 DateIssue      DateIssued ExistingUse ProposedUse  \
# 0  2018/01/26 14:30:02+00  Jan 26 2018  2        1-08        1-08
# 1  2017/02/15 13:22:21+00  Feb 15 2017  1          SF          SF
# 2  2019/06/14 15:30:05+00  Jun 14 2019  3        1-08        1-08
# 3  2018/07/12 15:00:05+00  Jul 12 2018  3        1-08        1-08
# 4  2019/07/12 15:30:07+00  Jul 12 2019  3        1-08        1-08
#
#   HousingMarketTypology2017  Council_District      Neighborhood  BLOCKLOT  \
# 0                         J                 9  Carrollton Ridge  0702 054
# 1                         J                 9  Carrollton Ridge  0703 003
# 2                         J                 9  Carrollton Ridge  0703 004
# 3                         J                 9  Carrollton Ridge  0703 006
# 4                         J                 9  Carrollton Ridge  0703 009
#
#             Address
# 0  2105 WILKENS AVE
# 1  2005 WILKENS AVE
# 2  2007 WILKENS AVE
# 3  2011 WILKENS AVE
# 4  2017 WILKENS AVE

# %%
rehab2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   X                          11814 non-null  float64
#  1   Y                          11814 non-null  float64
#  2   OBJECTID                   11814 non-null  int64
#  3   Block                      11814 non-null  object
#  4   Lot                        11814 non-null  object
#  5   PermitNum                  11814 non-null  object
#  6   VBN                        11814 non-null  object
#  7   DateIssue                  11814 non-null  object
#  8   DateIssued                 11814 non-null  object
#  9   ExistingUse                10855 non-null  object
#  10  ProposedUse                10855 non-null  object
#  11  HousingMarketTypology2017  11814 non-null  object
#  12  Council_District           11814 non-null  int64
#  13  Neighborhood               11814 non-null  object
#  14  BLOCKLOT                   11814 non-null  object
#  15  Address                    11814 non-null  object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 1.4+ MB

# %%
rehab.head()
# Out:
#               X              Y  OBJECTID Block  Lot      PermitNum VBN  \
# 0  1.411621e+06  588083.607549        11  0702  054  USE2017-53053   Y
# 1  1.412010e+06  588243.692202        17  0703  003  USE2016-04684   Y
# 2  1.411996e+06  588238.767015        18  0703  004  USE2018-56446   Y
# 3  1.411971e+06  588228.203388        20  0703  006  USE2018-52199   Y
# 4  1.411933e+06  588211.727043        23  0703  009  USE2019-52486   Y
#
#                 DateIssue      DateIssued ExistingUse ProposedUse  \
# 0  2018/01/26 14:30:02+00  Jan 26 2018  2        1-08        1-08
# 1  2017/02/15 13:22:21+00  Feb 15 2017  1          SF          SF
# 2  2019/06/14 15:30:05+00  Jun 14 2019  3        1-08        1-08
# 3  2018/07/12 15:00:05+00  Jul 12 2018  3        1-08        1-08
# 4  2019/07/12 15:30:07+00  Jul 12 2019  3        1-08        1-08
#
#   HousingMarketTypology2017  Council_District      Neighborhood  BLOCKLOT  \
# 0                         J                 9  Carrollton Ridge  0702 054
# 1                         J                 9  Carrollton Ridge  0703 003
# 2                         J                 9  Carrollton Ridge  0703 004
# 3                         J                 9  Carrollton Ridge  0703 006
# 4                         J                 9  Carrollton Ridge  0703 009
#
#             Address
# 0  2105 WILKENS AVE
# 1  2005 WILKENS AVE
# 2  2007 WILKENS AVE
# 3  2011 WILKENS AVE
# 4  2017 WILKENS AVE

# %%
rehab[['BLOCKLOT','Block','Lot']]
# Out:
#        BLOCKLOT  Block  Lot
# 0      0702 054   0702  054
# 1      0703 003   0703  003
# 2      0703 004   0703  004
# 3      0703 006   0703  006
# 4      0703 009   0703  009
# ...         ...    ...  ...
# 11809  6694E038  6694E  038
# 11810  7470E024  7470E  024
# 11811  6750E007  6750E  007
# 11812  6750E020  6750E  020
# 11813  7900E065  7900E  065
#
# [11814 rows x 3 columns]

# %%
date_issues = rehab[['DateIssue','DateIssued']].sort_values(by='DateIssue')
date_issues.head()
# Out:
#                    DateIssue      DateIssued
# 9742  2015/01/05 00:00:00+00  Jan  5 2015 12
# 1148  2015/01/05 00:00:00+00  Jan  5 2015 12
# 1756  2015/01/06 00:00:00+00  Jan  6 2015 12
# 4030  2015/01/06 00:00:00+00  Jan  6 2015 12
# 2347  2015/01/07 00:00:00+00  Jan  7 2015 12

# %%
rehab.duplicated().value_counts()
# Out:
# False    11814
# Name: count, dtype: int64

# %%
rehab.isnull().sum()
# Out:
# X                              0
# Y                              0
# OBJECTID                       0
# Block                          0
# Lot                            0
# PermitNum                      0
# VBN                            0
# DateIssue                      0
# DateIssued                     0
# ExistingUse                  959
# ProposedUse                  959
# HousingMarketTypology2017      0
# Council_District               0
# Neighborhood                   0
# BLOCKLOT                       0
# Address                        0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
rehab2.rename({
    'X':'Longitude',
    'Y':'Latitude',
    'OBJECTID':'Object ID'
},axis=1,inplace=True)
rehab2.head()

# %%
rehab2.drop(['DateIssued','BLOCKLOT'], inplace = True, axis = 1)
rehab2.head()
# Out:
#       Longitude       Latitude  Object ID Block  Lot      PermitNum VBN  \
# 0  1.411621e+06  588083.607549         11  0702  054  USE2017-53053   Y
# 1  1.412010e+06  588243.692202         17  0703  003  USE2016-04684   Y
# 2  1.411996e+06  588238.767015         18  0703  004  USE2018-56446   Y
# 3  1.411971e+06  588228.203388         20  0703  006  USE2018-52199   Y
# 4  1.411933e+06  588211.727043         23  0703  009  USE2019-52486   Y
#
#                 DateIssue ExistingUse ProposedUse HousingMarketTypology2017  \
# 0  2018/01/26 14:30:02+00        1-08        1-08                         J
# 1  2017/02/15 13:22:21+00          SF          SF                         J
# 2  2019/06/14 15:30:05+00        1-08        1-08                         J
# 3  2018/07/12 15:00:05+00        1-08        1-08                         J
# 4  2019/07/12 15:30:07+00        1-08        1-08                         J
#
#    Council_District      Neighborhood           Address
# 0                 9  Carrollton Ridge  2105 WILKENS AVE
# 1                 9  Carrollton Ridge  2005 WILKENS AVE
# 2                 9  Carrollton Ridge  2007 WILKENS AVE
# 3                 9  Carrollton Ridge  2011 WILKENS AVE
# 4                 9  Carrollton Ridge  2017 WILKENS AVE

# %%
rehab2['PermitNum']= rehab2['PermitNum'].astype('string')

# %%
rehab2['PermitNum'] = rehab2['PermitNum'].str.replace(r'^USE','',regex = True)
rehab2['PermitNum'].head(20)
# Out:
# 0     2017-53053
# 1     2016-04684
# 2     2018-56446
# 3     2018-52199
# 4     2019-52486
# 5     2015-01306
# 6     2023-51275
# 7     2018-53867
# 8     2019-54792
# 9     2023-54613
# 10    2024-53562
# 11    2024-54704
# 12    2018-52098
# 13    2024-51472
# 14    2023-52371
# 15    2016-05411
# 16    2016-05310
# 17    2015-02612
# 18    2022-53133
# 19    2018-53409
# Name: PermitNum, dtype: string

# %%
rehab2['PermitNum'].str.replace(r'^BUSE','', regex = True)
# Out:
# 0        2017-53053
# 1        2016-04684
# 2        2018-56446
# 3        2018-52199
# 4        2019-52486
#             ...
# 11809    2019-53664
# 11810    2023-55273
# 11811    2019-55213
# 11812    2016-04224
# 11813    2020-51378
# Name: PermitNum, Length: 11814, dtype: string

# %%
rehab2['PermitNum'].duplicated().value_counts()
# Out:
# PermitNum
# False    11814
# Name: count, dtype: int64

# %%
rehab2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  11814 non-null  float64
#  1   Latitude                   11814 non-null  float64
#  2   Object ID                  11814 non-null  int64
#  3   Block                      11814 non-null  object
#  4   Lot                        11814 non-null  object
#  5   PermitNum                  11814 non-null  string
#  6   VBN                        11814 non-null  object
#  7   DateIssue                  11814 non-null  object
#  8   ExistingUse                10855 non-null  object
#  9   ProposedUse                10855 non-null  object
#  10  HousingMarketTypology2017  11814 non-null  object
#  11  Council_District           11814 non-null  int64
#  12  Neighborhood               11814 non-null  object
#  13  Address                    11814 non-null  object
# dtypes: float64(2), int64(2), object(9), string(1)
# memory usage: 1.3+ MB

# %%
rehab2['HousingMarketTypology2017'].value_counts()
# Out:
# HousingMarketTypology2017
# I                            3176
# H                            2105
# F                            1628
# J                            1435
# E                            1070
# D                             807
# B                             645
# G                             555
# C                             232
# A                              98
# Rental Market 1                26
# Subsidized Rental Market       23
# NonResidential                  9
# Mixed Market/Subsd Rental       5
# Name: count, dtype: int64

# %%
rehab2['DateIssue'] = pd.to_datetime(rehab2['DateIssue'])
rehab2['DateIssue'].head()
# Out:
# 0   2018-01-26 14:30:02+00:00
# 1   2017-02-15 13:22:21+00:00
# 2   2019-06-14 15:30:05+00:00
# 3   2018-07-12 15:00:05+00:00
# 4   2019-07-12 15:30:07+00:00
# Name: DateIssue, dtype: datetime64[ns, UTC]

# %%
rehab2[['ExistingUse','ProposedUse']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ExistingUse  10855 non-null  object
#  1   ProposedUse  10855 non-null  object
# dtypes: object(2)
# memory usage: 184.7+ KB

# %%
rehab2['ExistingUse'] = rehab2['ExistingUse'].astype('string')
rehab2['ProposedUse'] = rehab2['ProposedUse'].astype('string')

missing = rehab2[rehab2['ExistingUse'].isnull()]
missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 959 entries, 28 to 11802
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  959 non-null    float64
#  1   Latitude                   959 non-null    float64
#  2   Object ID                  959 non-null    int64
#  3   Block                      959 non-null    object
#  4   Lot                        959 non-null    object
#  5   PermitNum                  959 non-null    string
#  6   VBN                        959 non-null    object
#  7   DateIssue                  959 non-null    datetime64[ns, UTC]
#  8   ExistingUse                0 non-null      string
#  9   ProposedUse                0 non-null      string
#  10  HousingMarketTypology2017  959 non-null    object
#  11  Council_District           959 non-null    int64
#  12  Neighborhood               959 non-null    object
#  13  Address                    959 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(6), string(3)
# memory usage: 112.4+ KB

# %%
mv = rehab2[rehab2['ExistingUse'].isnull()]
sv = []
for idx in mv.index:
  if idx > 0:
    sv.append(idx-1)
  sv.append(idx)
  if idx < len(rehab2) - 1:
    sv.append(idx + 1)
sv = sorted(set(sv))
svdf = rehab2.loc[sv]
svdf
# Out:
#           Longitude       Latitude  Object ID  Block  Lot       PermitNum VBN  \
# 27     1.413786e+06  589099.326318        737   0279  085      2015-02604   Y
# 28     1.410834e+06  588624.095313        740   0288  055  BUSE-25-002992   Y
# 29     1.413786e+06  589111.723931        741   0279  086      2015-02601   Y
# 36     1.414380e+06  589078.324391        782   0280  023      2024-55945   Y
# 37     1.414380e+06  589054.321487        784   0280  025  BUSE-25-005700   Y
# ...             ...            ...        ...    ...  ...             ...  ..
# 11799  1.429821e+06  621183.021009     245723  5210E  139      2024-50120   Y
# 11800  1.426325e+06  612828.289687     245795  5267E  041      2017-01535   Y
# 11801  1.425780e+06  612996.056412     245802  5267E  048      2024-55719   Y
# 11802  1.442061e+06  612122.753368     245927  5695E  012  BUSE-25-003115   Y
# 11803  1.443688e+06  611944.689748     245955  5733E  001      2016-05949   Y
#
#                       DateIssue ExistingUse ProposedUse  \
# 27    2016-04-15 00:00:00+00:00         VAC          SF
# 28    2025-08-20 00:00:00+00:00        <NA>        <NA>
# 29    2016-04-15 00:00:00+00:00         VAC          SF
# 36    2024-11-29 00:00:00+00:00        1-08        1-08
# 37    2025-11-19 00:00:00+00:00        <NA>        <NA>
# ...                         ...         ...         ...
# 11799 2025-08-28 00:00:00+00:00        <NA>        <NA>
# 11800 2018-04-24 08:50:52+00:00          SF          SF
# 11801 2024-11-20 00:00:00+00:00        1-08        1-08
# 11802 2025-07-15 00:00:00+00:00        <NA>        <NA>
# 11803 2017-05-08 10:22:26+00:00          SF          SF
#
#       HousingMarketTypology2017  Council_District      Neighborhood  \
# 27                            I                 9       Mount Clare
# 28                            J                 9  Carrollton Ridge
# 29                            I                 9       Mount Clare
# 36                            I                 9       Mount Clare
# 37                            I                 9       Mount Clare
# ...                         ...               ...               ...
# 11799                         D                 4          Idlewood
# 11800                         E                 4     New Northwood
# 11801                         E                 4     New Northwood
# 11802                         F                 2          Hamilton
# 11803                         D                 2           Cedmont
#
#                      Address
# 27          328 S PARRISH ST
# 28             422 FURROW ST
# 29          326 S PARRISH ST
# 36          344 S CALHOUN ST
# 37          348 S CALHOUN ST
# ...                      ...
# 11799         1424 LIMIT AVE
# 11800  4666 MARBLE HALL ROAD
# 11801       1201 WINSTON AVE
# 11802      4102 CENTURY ROAD
# 11803        4401 POWELL AVE
#
# [2553 rows x 14 columns]

# %%
rehab2['ExistingUse'].isna()
rehab2.ffill(inplace=True)
rehab2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  11814 non-null  float64
#  1   Latitude                   11814 non-null  float64
#  2   Object ID                  11814 non-null  int64
#  3   Block                      11814 non-null  object
#  4   Lot                        11814 non-null  object
#  5   PermitNum                  11814 non-null  string
#  6   VBN                        11814 non-null  object
#  7   DateIssue                  11814 non-null  datetime64[ns, UTC]
#  8   ExistingUse                11814 non-null  string
#  9   ProposedUse                11814 non-null  string
#  10  HousingMarketTypology2017  11814 non-null  object
#  11  Council_District           11814 non-null  int64
#  12  Neighborhood               11814 non-null  object
#  13  Address                    11814 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(6), string(3)
# memory usage: 1.3+ MB

# %%
string_col = rehab2.select_dtypes(include=['string']).columns
for col in string_col:
  rehab2[col] = rehab2[col].astype('object')
rehab2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  11814 non-null  float64
#  1   Latitude                   11814 non-null  float64
#  2   Object ID                  11814 non-null  int64
#  3   Block                      11814 non-null  object
#  4   Lot                        11814 non-null  object
#  5   PermitNum                  11814 non-null  object
#  6   VBN                        11814 non-null  object
#  7   DateIssue                  11814 non-null  datetime64[ns, UTC]
#  8   ExistingUse                11814 non-null  object
#  9   ProposedUse                11814 non-null  object
#  10  HousingMarketTypology2017  11814 non-null  object
#  11  Council_District           11814 non-null  int64
#  12  Neighborhood               11814 non-null  object
#  13  Address                    11814 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(9)
# memory usage: 1.3+ MB

# %%
rehab2.head(5)
# Out:
#       Longitude       Latitude  Object ID Block  Lot   PermitNum VBN  \
# 0  1.411621e+06  588083.607549         11  0702  054  2017-53053   Y
# 1  1.412010e+06  588243.692202         17  0703  003  2016-04684   Y
# 2  1.411996e+06  588238.767015         18  0703  004  2018-56446   Y
# 3  1.411971e+06  588228.203388         20  0703  006  2018-52199   Y
# 4  1.411933e+06  588211.727043         23  0703  009  2019-52486   Y
#
#                   DateIssue ExistingUse ProposedUse HousingMarketTypology2017  \
# 0 2018-01-26 14:30:02+00:00        1-08        1-08                         J
# 1 2017-02-15 13:22:21+00:00          SF          SF                         J
# 2 2019-06-14 15:30:05+00:00        1-08        1-08                         J
# 3 2018-07-12 15:00:05+00:00        1-08        1-08                         J
# 4 2019-07-12 15:30:07+00:00        1-08        1-08                         J
#
#    Council_District      Neighborhood           Address
# 0                 9  Carrollton Ridge  2105 WILKENS AVE
# 1                 9  Carrollton Ridge  2005 WILKENS AVE
# 2                 9  Carrollton Ridge  2007 WILKENS AVE
# 3                 9  Carrollton Ridge  2011 WILKENS AVE
# 4                 9  Carrollton Ridge  2017 WILKENS AVE

# %% [markdown]
# KPIs

# %%
# !pip install streamlit
import streamlit as st
# Out:
# Collecting streamlit
#   Downloading streamlit-1.55.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.55.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 43.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 37.2 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.55.0

# %%
rehab2.head()
# Out:
#       Longitude       Latitude  Object ID Block  Lot   PermitNum VBN  \
# 0  1.411621e+06  588083.607549         11  0702  054  2017-53053   Y
# 1  1.412010e+06  588243.692202         17  0703  003  2016-04684   Y
# 2  1.411996e+06  588238.767015         18  0703  004  2018-56446   Y
# 3  1.411971e+06  588228.203388         20  0703  006  2018-52199   Y
# 4  1.411933e+06  588211.727043         23  0703  009  2019-52486   Y
#
#                   DateIssue ExistingUse ProposedUse HousingMarketTypology2017  \
# 0 2018-01-26 14:30:02+00:00        1-08        1-08                         J
# 1 2017-02-15 13:22:21+00:00          SF          SF                         J
# 2 2019-06-14 15:30:05+00:00        1-08        1-08                         J
# 3 2018-07-12 15:00:05+00:00        1-08        1-08                         J
# 4 2019-07-12 15:30:07+00:00        1-08        1-08                         J
#
#    Council_District      Neighborhood           Address
# 0                 9  Carrollton Ridge  2105 WILKENS AVE
# 1                 9  Carrollton Ridge  2005 WILKENS AVE
# 2                 9  Carrollton Ridge  2007 WILKENS AVE
# 3                 9  Carrollton Ridge  2011 WILKENS AVE
# 4                 9  Carrollton Ridge  2017 WILKENS AVE

# %%
st.title('Vacant Buildings Dashboard')
group_col = st.selectbox('Group By:', ['Neighborhood','ExistingUse','ProposedUse','Council_District'])
breakdown = st.checkbox('Breakdown Further')
if breakdown:
  breakdown_col = st.selectbox('Breakdown By:', ['ExistingUse','ProposedUse','Council_District'])
  grouped_df = rehab2.groupby([group_col, breakdown_col]).size().reset_index(name = 'Count')
  fig = px.bar(grouped_df, x = group_col, y = 'Count', color = breakdown_col)
else:
  group_df = rehab2.groupby(group_col).size().reset_index(name = 'Count')
  fig = px.bar(group_df, x = group_col, y = 'Count')
  st.plotly_chart(fig)
# Out:
# 2026-03-30 23:30:58.667 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.114
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-03-30 23:30:59.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.135 Session state does not function when running a script without `streamlit run`
# 2026-03-30 23:30:59.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:30:59.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:31:00.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:31:00.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:31:00.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:31:00.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-30 23:31:00.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.107.196.235:8501

# %% [markdown]
# # Exploratory Data Analysis

# %%
rehab2.columns

# %%
rehab2.head()

# %% [markdown]
# ##Time Based EDA

# %%
from pandas.core import resample
import plotly.express as px
monthly = (rehab2.dropna(subset = ['DateIssue'])
.set_index('DateIssue')
.resample('MS')
.size()
)
df_monthly = monthly.reset_index()
df_monthly.columns = ['DateIssue','Count']
fig = px.line(df_monthly, x = 'DateIssue', y = 'Count', title = 'Permits Over Time',
              labels = {'DateIssue':'Month','Count':"Count"})
fig.update_layout(width = 1200, height = 600)
fig.show()

# %% [markdown]
# ##Annual Permit Count

# %%
annual = (rehab2.dropna(subset = 'DateIssue')
.set_index('DateIssue')
.resample('AS')
.size()
)
df_annual = annual.reset_index()
df_annual.columns = ['Year','Count']
fig = px.bar(df_annual, x = 'Year', y = 'Count')
fig.update_layout(width = 1200, height = 600)
fig.show()

# %% [markdown]
# ##

# %%
heatmap_df = df_monthly.copy()
heatmap_df = heatmap_df.reset_index()
heatmap_df['Year'] = heatmap_df['DateIssue'].dt.year
heatmap_df['Month'] = heatmap_df['DateIssue'].dt.month

pivot = heatmap_df.pivot_table(
    index = 'Year',
    columns = 'Month',
    values = 'Count')

pivot = pivot.sort_index(axis = 1)


fig_heat = px.imshow(
    pivot,
    aspect='auto',
    color_continuous_scale='Viridis',
    labels = dict(x = 'Month', y = 'Year', color = 'Count'),
    title = 'Monthly/Annual Permit Volume'
)
fig_heat.update_layout(width = 1200, height = 600)
fig_heat.show()

# %% [markdown]
# ## Geo

# %%
rehab2.head()

# %%
import geopandas as gpd
from shapely.geometry import Point

gdf = gpd.GeoDataFrame(
    rehab2,
    geometry = [Point(xy) for xy in zip(rehab2['Longitude'], rehab2['Latitude'])],
    crs = 'EPSG:2248'
)
gdf = gdf.to_crs(epsg = 4326)
gdf['Latitude'] = gdf['geometry'].y
gdf['Longitude'] = gdf['geometry'].x


fig = px.scatter_mapbox(gdf,
      lat = 'Latitude',
      lon = 'Longitude',
      opacity = 0.5,
      zoom = 10
      )
fig.update_layout(mapbox_style = 'carto-positron',
                height = 800)
fig.show()

# %%
neighborhood_permits = (
    rehab2.groupby('Neighborhood')
    .size()
    .reset_index(name = 'Count')
    .sort_values(by = 'Count', ascending = False)
)

fig = px.bar(neighborhood_permits, x = 'Neighborhood', y = 'Count')
fig.update_layout(width = 1200, height = 600)
fig.show()

# %%
neighorhood_heatmap_df = rehab2.copy()
neighorhood_heatmap_df = neighorhood_heatmap_df.reset_index()
neighorhood_heatmap_df['Year'] = neighorhood_heatmap_df['DateIssue'].dt.year
neighorhood_heatmap_df['Count'] = neighorhood_heatmap_df.groupby('Neighborhood')['Neighborhood'].transform('count')


pivot1 = neighorhood_heatmap_df.pivot_table(
    index = 'Year',
    columns = 'Neighborhood',
    values = 'Count')

pivot1 = pivot1.sort_index(axis = 1)
fig_nhm = px.imshow(
    pivot1,
    aspect='auto',
    color_continuous_scale='Viridis',
    labels = dict(x = 'Neighborhood', y = 'Year', color = 'Count'),
    title = ''
)
fig_nhm.update_layout(width = 1200, height = 600)
fig_nhm.show()

# %% [markdown]
# ## Categorical

# %%
existing_use_order = rehab2['ExistingUse'].value_counts().index

fig = px.histogram(rehab2, x='ExistingUse', color='ExistingUse',
                   title='Existing Use Distribution',
                   labels={'ExistingUse':'Existing Use','count':'Total'},
                   category_orders={'ExistingUse': existing_use_order}
                  )
fig.update_layout(width=1200, height=600)
fig.show()

# %%
proposed_use_order = rehab2['ProposedUse'].value_counts().index

fig = px.histogram(rehab2, x='ProposedUse', color='ProposedUse',
                   title='Proposed Use Distribution',
                   labels={'ProposedUse':'Proposed Use','count':'Total'},
                   category_orders={'ProposedUse': proposed_use_order}
                  )
fig.update_layout(width=1200, height=600)
fig.show()

# %% [markdown]
# # Data Preprocessing

# %%
rehab3 = rehab2.copy()

# %%
rehab3['Year'] = rehab2['DateIssue'].dt.year
rehab3['Month'] = rehab2['DateIssue'].dt.month
rehab3['Day'] = rehab2['DateIssue'].dt.day
rehab3['Time'] = rehab2['DateIssue'].dt.time
rehab3.drop('DateIssue', inplace = True, axis = 1)
rehab3.head()
# Out:
#       Longitude       Latitude  Object ID Block  Lot   PermitNum VBN  \
# 0  1.411621e+06  588083.607549         11  0702  054  2017-53053   Y
# 1  1.412010e+06  588243.692202         17  0703  003  2016-04684   Y
# 2  1.411996e+06  588238.767015         18  0703  004  2018-56446   Y
# 3  1.411971e+06  588228.203388         20  0703  006  2018-52199   Y
# 4  1.411933e+06  588211.727043         23  0703  009  2019-52486   Y
#
#   ExistingUse ProposedUse HousingMarketTypology2017  Council_District  \
# 0        1-08        1-08                         J                 9
# 1          SF          SF                         J                 9
# 2        1-08        1-08                         J                 9
# 3        1-08        1-08                         J                 9
# 4        1-08        1-08                         J                 9
#
#        Neighborhood           Address  Year  Month  Day      Time
# 0  Carrollton Ridge  2105 WILKENS AVE  2018      1   26  14:30:02
# 1  Carrollton Ridge  2005 WILKENS AVE  2017      2   15  13:22:21
# 2  Carrollton Ridge  2007 WILKENS AVE  2019      6   14  15:30:05
# 3  Carrollton Ridge  2011 WILKENS AVE  2018      7   12  15:00:05
# 4  Carrollton Ridge  2017 WILKENS AVE  2019      7   12  15:30:07

# %%
drop_cols = ['Object ID','Block','VBN','Lot','PermitNum','Time','Address','Neighborhood','Day','Council_District']

# %%
X = rehab3.drop(columns = drop_cols, errors = 'ignore')
rehab3.shape, X.shape
# Out:
# ((11814, 17), (11814, 7))

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

num_features = ['Year','Month']
cat_features = ['ExistingUse','ProposedUse']
geo_features = ['Longitude','Latitude']

num_pipeline = Pipeline(steps = [
    #('imputer', SimpleImputer(strategy = 'median')),
    ('scaler', StandardScaler())
])

cat_pipeline = Pipeline(steps = [
   # ('imputer', SimpleImputer(strategy = 'most_frequent'))
('onehot', OneHotEncoder(handle_unknown = 'ignore'))
])

geo_pipeline = Pipeline(steps = [
    ('scaler', StandardScaler())
])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_pipeline, num_features),
        ('cat', cat_pipeline, cat_features),
        ('geo', geo_pipeline, geo_features)
    ],
    remainder='drop'
)

# %%
num_features
# Out:
# ['Year', 'Month']

# %%
X_proc = preprocessor.fit_transform(X)

# %%
def elbow_silhouette(
    X_proc,
    k_min=2,
    k_max=12,
    random_state=42):
  ks = list(range(k_min, k_max + 1))
  inertias, silhouettes = [], []


  for k in ks:
      km = KMeans(n_clusters=k, random_state=random_state, n_init="auto")
      labels = km.fit_predict(X_proc)
      inertias.append(km.inertia_)
      silhouettes.append(silhouette_score(X_proc, labels, sample_size = 5000, random_state=random_state))

      return ks, inertias, silhouettes

# %%
ks, inertias, silhouettes = elbow_silhouette(
    X_proc,
    k_min=2,
    k_max=12,
    random_state=42

)

best_k = ks[int(np.argmax(silhouettes))]
print(f"Best k by silhouette: {best_k} (score={max(silhouettes):.4f})")
# Out:
# Best k by silhouette: 2 (score=0.2345)

# %%
X.columns.tolist()
# Out:
# ['Longitude',
#  'Latitude',
#  'ExistingUse',
#  'ProposedUse',
#  'HousingMarketTypology2017',
#  'Year',
#  'Month']

# %%
num_features, cat_features, geo_features
# Out:
# (['Year', 'Month'], ['ExistingUse', 'ProposedUse'], ['Longitude', 'Latitude'])

# %%
rehab3.dtypes
# Out:
# Longitude                    float64
# Latitude                     float64
# Object ID                      int64
# Block                         object
# Lot                           object
# PermitNum                     object
# VBN                           object
# ExistingUse                   object
# ProposedUse                   object
# HousingMarketTypology2017     object
# Council_District               int64
# Neighborhood                  object
# Address                       object
# Year                           int32
# Month                          int32
# Day                            int32
# Time                          object
# dtype: object

# %%
import geopandas as gpd
gdf = gpd.GeoDataFrame(rehab3)
gdf.set_geometry(gpd.points_from_xy(gdf.Longitude, gdf.Latitude), inplace=True)
gdf
# Out:
#           Longitude       Latitude  Object ID  Block  Lot   PermitNum VBN  \
# 0      1.411621e+06  588083.607549         11   0702  054  2017-53053   Y
# 1      1.412010e+06  588243.692202         17   0703  003  2016-04684   Y
# 2      1.411996e+06  588238.767015         18   0703  004  2018-56446   Y
# 3      1.411971e+06  588228.203388         20   0703  006  2018-52199   Y
# 4      1.411933e+06  588211.727043         23   0703  009  2019-52486   Y
# ...             ...            ...        ...    ...  ...         ...  ..
# 11809  1.439486e+06  589084.359812     246591  6694E  038  2019-53664   Y
# 11810  1.413831e+06  577866.201475     246647  7470E  024  2023-55273   Y
# 11811  1.443578e+06  585196.813782     246684  6750E  007  2019-55213   Y
# 11812  1.443657e+06  585330.824997     246690  6750E  020  2016-04224   Y
# 11813  1.396822e+06  592675.501908     246861  7900E  065  2020-51378   Y
#
#       ExistingUse ProposedUse HousingMarketTypology2017  Council_District  \
# 0            1-08        1-08                         J                 9
# 1              SF          SF                         J                 9
# 2            1-08        1-08                         J                 9
# 3            1-08        1-08                         J                 9
# 4            1-08        1-08                         J                 9
# ...           ...         ...                       ...               ...
# 11809        1-08        1-08                         D                 1
# 11810        1-08        1-08                         H                10
# 11811        3-35        3-35                         F                 1
# 11812         VAC          SF                         F                 1
# 11813        1-11        1-11                         E                 8
#
#            Neighborhood              Address  Year  Month  Day      Time  \
# 0      Carrollton Ridge     2105 WILKENS AVE  2018      1   26  14:30:02
# 1      Carrollton Ridge     2005 WILKENS AVE  2017      2   15  13:22:21
# 2      Carrollton Ridge     2007 WILKENS AVE  2019      6   14  15:30:05
# 3      Carrollton Ridge     2011 WILKENS AVE  2018      7   12  15:00:05
# 4      Carrollton Ridge     2017 WILKENS AVE  2019      7   12  15:30:07
# ...                 ...                  ...   ...    ...  ...       ...
# 11809         Greektown         837 TOLNA ST  2019      7   31  12:01:25
# 11810          Lakeland   2924 MALLVIEW ROAD  2023     10   27  00:00:00
# 11811    Broening Manor    6416 HOLABIRD AVE  2020      1   17  00:00:00
# 11812    Broening Manor         1700 KANE ST  2017      1   25  09:18:34
# 11813     Hunting Ridge  610 NOTTINGHAM ROAD  2020      8   21  00:00:00
#
#                              geometry
# 0       POINT (1411621.02 588083.608)
# 1      POINT (1412009.592 588243.692)
# 2      POINT (1411996.418 588238.767)
# 3      POINT (1411970.857 588228.203)
# 4      POINT (1411932.617 588211.727)
# ...                               ...
# 11809   POINT (1439486.259 589084.36)
# 11810  POINT (1413830.517 577866.201)
# 11811  POINT (1443578.454 585196.814)
# 11812  POINT (1443657.461 585330.825)
# 11813  POINT (1396822.477 592675.502)
#
# [11814 rows x 18 columns]

# %%
# To fix the 'NoneType' error due to a previous incorrect assignment to 'gdf',
# we explicitly re-create the GeoDataFrame 'gdf' using the 'rehab3' DataFrame.
# Ideally, the cell where 'gdf' was originally defined (EthBm8pOQLTz) should be re-run,
# but this ensures the current cell executes correctly.
gdf = gpd.GeoDataFrame(rehab3)
gdf.set_geometry(gpd.points_from_xy(gdf.Longitude, gdf.Latitude), inplace=True)

gdf.to_file("gdf.shp")
gdf.head()
# Out:
#       Longitude       Latitude  Object ID Block  Lot   PermitNum VBN  \
# 0  1.411621e+06  588083.607549         11  0702  054  2017-53053   Y
# 1  1.412010e+06  588243.692202         17  0703  003  2016-04684   Y
# 2  1.411996e+06  588238.767015         18  0703  004  2018-56446   Y
# 3  1.411971e+06  588228.203388         20  0703  006  2018-52199   Y
# 4  1.411933e+06  588211.727043         23  0703  009  2019-52486   Y
#
#   ExistingUse ProposedUse HousingMarketTypology2017  Council_District  \
# 0        1-08        1-08                         J                 9
# 1          SF          SF                         J                 9
# 2        1-08        1-08                         J                 9
# 3        1-08        1-08                         J                 9
# 4        1-08        1-08                         J                 9
#
#        Neighborhood           Address  Year  Month  Day      Time  \
# 0  Carrollton Ridge  2105 WILKENS AVE  2018      1   26  14:30:02
# 1  Carrollton Ridge  2005 WILKENS AVE  2017      2   15  13:22:21
# 2  Carrollton Ridge  2007 WILKENS AVE  2019      6   14  15:30:05
# 3  Carrollton Ridge  2011 WILKENS AVE  2018      7   12  15:00:05
# 4  Carrollton Ridge  2017 WILKENS AVE  2019      7   12  15:30:07
#
#                          geometry
# 0   POINT (1411621.02 588083.608)
# 1  POINT (1412009.592 588243.692)
# 2  POINT (1411996.418 588238.767)
# 3  POINT (1411970.857 588228.203)
# 4  POINT (1411932.617 588211.727)
